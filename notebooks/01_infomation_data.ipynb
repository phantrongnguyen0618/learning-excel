# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import numpy as np

# %%
data = pd.read_excel('0_Resources/Datasets/data_jobs_salary_monthly.xlsx')
data.head(10)
# Out:
#          job_title_short                                          job_title  \
# 0         Data Scientist                        Data Scientist - TikTok Ads
# 1         Data Scientist                Data Scientist - Technical Platform
# 2         Data Scientist                   Data Scientist - Computer Vision
# 3         Data Scientist  Senior Actuarial Consultant and Data Scientist...
# 4         Data Scientist  Data Scientist Digital Effectiveness Operation...
# 5         Data Scientist               Data Scientist - Marketing Analytics
# 6    Senior Data Analyst  Senior Data Analyst Business Optimization Inte...
# 7          Data Engineer  IT & Strategy Talent Programme - AI/ML and Dat...
# 8  Senior Data Scientist                              Senior Data Scientist
# 9          Data Engineer                                      Data Engineer
#
#               job_location                    job_via job_schedule_type  \
# ...

# %%
data.shape
# Out:
# (3102, 16)

# %%
data.columns
# Out:
# Index(['job_title_short', 'job_title', 'job_location', 'job_via',
#        'job_schedule_type', 'job_work_from_home', 'search_location',
#        'job_posted_date', 'job_no_degree_mention', 'job_health_insurance',
#        'job_country', 'salary_rate', 'salary_year_avg', 'salary_hour_avg',
#        'company_name', 'job_skills'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3102 entries, 0 to 3101
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   job_title_short        3102 non-null   object
#  1   job_title              3102 non-null   object
#  2   job_location           3080 non-null   object
#  3   job_via                3102 non-null   object
#  4   job_schedule_type      3090 non-null   object
#  5   job_work_from_home     3102 non-null   bool
#  6   search_location        3102 non-null   object
#  7   job_posted_date        3102 non-null   datetime64[ns]
#  8   job_no_degree_mention  3102 non-null   bool
#  9   job_health_insurance   3102 non-null   bool
#  10  job_country            3102 non-null   object
#  11  salary_rate            3102 non-null   object
#  12  salary_year_avg        2287 non-null   float64
#  13  salary_hour_avg        815 non-null    float64
# ...

# %%
data.isnull().sum()
# Out:
# job_title_short             0
# job_title                   0
# job_location               22
# job_via                     0
# job_schedule_type          12
# job_work_from_home          0
# search_location             0
# job_posted_date             0
# job_no_degree_mention       0
# job_health_insurance        0
# job_country                 0
# salary_rate                 0
# salary_year_avg           815
# salary_hour_avg          2287
# company_name                0
# job_skills                281
# dtype: int64

# %%
data['job_posted_date'].value_counts()
# Out:
# job_posted_date
# 2023-01-03 23:35:29    8
# 2023-01-11 06:05:08    6
# 2023-01-11 06:05:10    6
# 2023-01-03 23:32:51    5
# 2023-01-03 23:33:27    3
#                       ..
# 2023-01-11 04:40:25    1
# 2023-01-18 17:00:12    1
# 2023-01-31 21:01:25    1
# 2023-01-14 16:06:19    1
# 2023-01-04 00:29:40    1
# Name: count, Length: 2997, dtype: int64
